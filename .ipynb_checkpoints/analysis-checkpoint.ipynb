# %%
fra_scores = []
with open('devtest/fra_Latn.devtest.divergent_scores', 'r') as f:
    f = f.readlines()[1:]
    for id_, line in enumerate(f):
        
        score = float(line.rstrip().split('\t')[0])
        if score > 10:
            fra_scores.append(id_)
            
spa_scores = []
with open('devtest/spa_Latn.devtest.divergent_scores', 'r') as f:
    f = f.readlines()[1:]
    for id_, line in enumerate(f):
        
        score = float(line.rstrip().split('\t')[0])
        if score > 10:
            spa_scores.append(id_)

# %%
z = list(set(fra_scores).intersection(set(spa_scores)))

# %%
output = open('devtest/spa_Latn.devtest.equivalents_', 'w')

with open('devtest/spa_Latn.devtest', 'r') as f:
    f = f.readlines()
    for a in z:
        output.write(f[a])
        print(f[a])
output.close()
# Out:
# Capital de Samoa, la ciudad de Apia se ubica en la isla de Upolu y cuenta con poco menos de 40 000 habitantes.
#
# La gente puede no prever que la tolerancia y la comprensión también son necesarias para los viajeros de regreso en sus hogares.
#
# Al igual que otros especialistas, es escéptico acerca de si la diabetes tiene cura y remarca que estos descubrimientos no son relevantes para quienes que ya padecen de diabetes de tipo 1.
#
# No es posible que las recetas de la antigua Roma incluyeran alimentos que llegaron a Europa desde América o Asia siglos después.
#
# Danius declaró: «Actualmente no estamos haciendo nada. Llamé y envié correos electrónicos a su asistente más cercano y recibí contestaciones muy cordiales. Por el momento, eso es sin dudas suficiente».
#
# Con anterioridad, el director ejecutivo de Ring, Jamie Siminoff, mencionó que la compañía había iniciado a raíz de que el timbre de su entrada no podía oírse desde la tienda que tenía montada en su garaje.
#
# En el distrito de North Harbour, en el Océano Pacífico, se encuentran las playas de North Shore, que despliegan desde Long Bay, en el norte, hasta Devonport, en el sur.
#
# El espectáculo de luces y el sonido piramidal son una de las cosas más interesantes para los niños en la zona.
#
# Hacia fines del año 2017, Siminoff hizo una aparición en el canal de compras televisadas QVC.
#
# En la oscuridad, se pueden ver las pirámides y contemplarlas en silencio antes de que empiece el espectáculo.
#
# Es posible que haya más mares en el lado cercano debido a que su corteza es más delgada, lo que facilitó a la lava ascender a la superficie.
#
# En la tierra de Canaán no había bosques grandes; por ello, la madera era extremadamente costosa.
#
# Si bien cada país por separado era «escandinavo», existían marcadas diferencias en relación al pueblo, los monarcas, los hábitos y la historia entre Dinamarca, Suecia, Noruega e Islandia.
#
# La Declaración de la Independencia tiene escrito en su reverso la frase «Declaración de Independencia original del 4 de julio de 1776». El texto figura en la parte inferior del documento, boca abajo.
#
# El filme, protagonizado por Tyan Gosling y Emma Stone, fue nominado en todas las categorías más importantes.
#
# En definitiva, no debería causarnos sorpresa si nuestros propios predecesores resolvían sus «problemas proteicos» del mismo modo que los chimpancés de la sabana en la actualidad.
#
# El inspector general adjunto, D.K. Arya, declaró: «Hemos puesto bajo arresto a cinco individuos que abusaron de la mujer suiza y recuperamos su teléfono móvil y su computadora portátil».
#
# El portavoz de Medecines Sans Frontiere, Richard Veerman, comentó: «Angola se dirige hacia el brote más severo que jamás haya enfrentado y su situación continúa siendo muy grave».
#
# El domingo por la noche, en un anuncio realizado mediante el secretario de prensa, el presidente de los Estados Unidos de América, Donald Trump, comunicó que las tropas estadounidenses se retirarían de Siria.
#
# Si bien las bases del budismo tibetano son las enseñanzas de Buda, se extendieron por el sendero del amor Mahayana y numerosas técnicas del yoga de la India.
#
# Angel (2006) explica el enfoque continuo como un método utilizado para ayudar a las organizaciones a lograr un mayor nivel de desempeño.
#
# Cualquier persona que se proponga conducir en latitudes altas o en pasos de montañas debe prever la posibilidad de que haya nieve, hielo o bajas temperaturas.
#
# Además, la visibilidad puede reducirse por nevadas o por la condensación o el hielo que se forma en las ventanas del automóvil.
#
# Las velocidades del estándar 802.11n son mucho más altas que las alcanzadas por los que lo precedieron, con un rendimiento teórico máximo de 600 Mbps.
#
# A fines de 2015, TogiNet instaló la estación AstroNet Radio como una filial.
#
# Esmirna es la tercera ciudad más importante de Turquía, con aproximadamente 3.7 millones de habitantes, el segundo puerto más grande luego de Estambul y una muy buena central de transporte.
#
# Hu incentivó a los estados en vías de desarrollo a «no volver al tradicional camino de contaminar primero y hacer limpieza después».
#
# Sudáfrica venció a los All Blacks, de Nueva Zelanda, en un partido de rugby de las Tres Naciones, en el estadio Royal Bafokeng, en Rustenburg, Sudáfrica.
#
# El ministerio se pronunció en relación al retraso en el informe de Apple, diciendo que era algo «verdaderamente lamentable».
#
# En Scotturb, el autobús 403 se dirige con regularidad a Sintra y para en Cabo da Roca.
#
# El epicentro del sismo se localizó cerca de 20 km (15 mi) al nornoreste de Dillon y a casi 65 km (40 mi) al sur de Butte.
#
# La cuestión que dio origen al debate fue la controversia en torno al presupuesto destinado al socorro y reconstrucción posteriores al huracán Katrina, medida que algunos conservadores fiscales etiquetaron en torno de broma como el «Acuerdo de Nueva Orleans de Bush».
#
# El reclamo de Chambers contra Dios se fundaba en «la muerte por doquier, destrucción y terror de millones y millones de personas en el planeta».
#
# Recibió formación en obstetricia e ingresó a trabajar para el Hospital Nacional de Mujeres de Auckland hacia 1959.
#
# La historia que narra la ópera francesa presentada por Camille Saint-Saens es la de un artista «cuya vida está prescrita por el amor, por las drogas y por Japón».
#
# La región limita con el Sahel al norte, y con el Océano Atlántico al sur y al oeste.
#
# Los parisinos tienen reputación de egocéntricos, descorteses y engreídos.
#
# Robin Uthappa obtuvo la mayor puntuación en entradas: 70 anotaciones con solo 41 bolas, al conectar 11 cuatros y 2 seises.
#
# Julia Gillard, primera ministra interina, sostuvo, durante la campaña de las elecciones federales de 2010, que consideraba que Australia debería pasar a ser una república una vez finalizado el mandato de la reina Isabel II.
#
# En los pueblos del interior del norte de la India y Pakistán, se suele usar el yogur en el curry. En el sur de la India y en otros sectores costeros del subcontinente, es habitual consumir leche de coco.
#
# Nada puede verse más que el maravilloso cielo despejado y las numerosas montañas de los alrededores. Desde el interior de esta cueva, se puede ver u oír muy poco de este mundo.
#
# Gordon Johndroe, vocero de Bush, se refirió al compromiso norcoreano como «un avance importante hacia el objetivo de alcanzar la desnuclearización constatable de la península de Corea».
#
# En 1990, fue incorporado al listado de lugares del patrimonio de la humanidad en riesgo, producto de la amenaza de las arenas del desierto.
#
# Los deportes de nieve en descenso, como el esquí y la tablanieve, son disciplinas populares que consisten en deslizarse con esquís o una tabla fijada a los pies, sobre un terreno nevado.
#
# Debido a la preocupación generada por la posible falta de transporte, se consideró la posibilidad de que el juego se realizara a puertas cerradas, sin los fanáticos del equipo.
#
# Esquiar es una actividad principal de viaje con muchos adeptos, en ocasiones llamados «amantes del esquí», que organizan sus vacaciones completamente en base al esquí en un sitio específico.
#
# Esta es una de las atracciones más importantes de Sudáfrica y se la reconoce como ícono principal de los Parques Nacionales de Sudáfrica (SANParks).
#
# Pronunciar el italiano es relativamente sencillo, dado que la mayor parte de sus palabras suenan igual a como se escriben.
#
# La Meseta de Guiza, o «Necrópolis de Guiza», en el Valle de los Muertos, en Egipto, contiene numerosas pirámides (de las cuales la Gran Pirámide es la de mayor tamaño), varias tumbas pequeñas, templos, y la gran Esfinge.
#
# Aunque se fue del programa en 1993, conservó el título de productor ejecutivo y siguió percibiendo decenas de millones de dólares en regalías temporada tras temporada.
#
# Puede hacerse muy delgado y adherirse a otro metal. Es tal la delgadez que puede lograrse que se solía usar para decorar las ilustraciones hechas a mano en libros llamados «manuscritos iluminados».
#
# La Alta Edad Media fue precedida por la Temprana Edad Media y le siguió la Edad Media Tardía que, por convención, finaliza cerca del 1500.
#
# Actualmente, los científicos sostienen que esta economía masiva del carbono ha privado a la biosfera de uno de sus estados regulares que ha contribuido con la evolución de la humanidad por los últimos dos millones de años.
#
# Durante una entrevista, señaló que la nueva variante generaba «mucha preocupación y alarma, dada su elevada tasa de mortalidad».
#
# Reconocidos cantantes nacionales interpretaron bhajans, o canciones de devoción, a los pies del Shri Shyam.
#
# Por lo general, las hembras se relacionan estrechamente entre sí, lo que las hace una gran familia de hermanas e hijas.
#
# De modo semejante a lo que ocurre con un control remoto de televisión, este control está provisto de dos sensores ubicados cerca del televisor del usuario, posibilitando la triangulación de su posición en un espacio tridimensional.
#
# Argentina es famosa por contar con uno de los mejores equipos y los mejores jugadores de polo a nivel mundial.
#
# El torneo más importante del año tiene lugar en diciembre en los campos de polo de Las Cañitas.
#
# Normalmente, un curso abarcará todos los temas que se han tratado aquí con mucho más detalle y, en general, con experiencia práctica.
#
# Si viaja a las regiones árticas o antárticas en época invernal, vivirá la experiencia de la noche polar, que significa que el sol no se alza por encima del horizonte.
#
# Con frecuencia, los trabajadores deben contar con la aprobación de sus superiores para la toma de decisiones y se espera que obedezcan sus instrucciones sin cuestionamiento.
#
# Si bien las pirámides de piedra continuaron construyéndose hasta el final del Reino Antiguo, nunca pudo superarse a las de Guiza, ni en tamaño ni en lo sublime de la técnica de su edificación.
#
# De todas formas, se cree que no han causado ningún daño al trasbordador.
#
# El nuevo entorno cuenta con distintos recursos y competidores y, por lo tanto, una nueva población necesitará características o adaptaciones diferentes de las que tenía antes para ser un competidor fuerte.
#
# «Perdí a mi hermana y a su amiga, y, de regreso, vi a dos personas en silla de ruedas y los demás les saltaban por encima y las empujaban», relató Armand Versace.
#
# Se informó que alrededor de 9400 viviendas de la región se encuentran si suministro de agua y unas 100 sin electricidad.

# %%
len(spa_scores)
# Out:
# 158

# %%
len(fra_scores)
# Out:
# 344

# %%
output = open('devtest/ell_Grek.devtest.equivalents', 'w')

with open('devtest/ell_Grek.devtest', 'r') as f:
    f = f.readlines()
    for a in z:
        output.write(f[a])
        print(f[a])
output.close()
# Out:
# Η Απία είναι η πρωτεύουσα της Σαμόα. Η πόλη βρίσκεται στο νησί Ουπόλου και έχει σχεδόν 40.000 κατοίκους.
#
# Πολλοί μπορεί να μην προβλέψουν την υπομονή και την κατανόηση που χρειάζεται στους ταξιδιώτες για την επιστροφή στο σπίτι.
#
# Όπως και κάποιοι άλλοι ειδικοί, είναι επιφυλακτικός με το εάν ο διαβήτης μπορεί να θεραπευτεί, επισημαίνοντας πως αυτά τα ευρήματα δεν συσχετίζονται καθόλου με τα άτομα που πάσχουν ήδη από διαβήτη τύπου 1.
#
# Τα γεύματα στην αρχαία Ρώμη δεν θα μπορούσαν να περιέχουν τρόφιμα που έφτασαν στην Ευρώπη από την Αμερική ή την Ασία τους μετέπειτα αιώνες.
#
# Ο Ντάνιους είπε, «Τώρα δεν κάνουμε τίποτα. Έχω μιλήσει τηλεφωνικά και με μέιλ με τον πιο κοντινό συνεργάτη του και πήρα πολύ φιλικές απαντήσεις. Για τώρα, αυτό σίγουρα είναι αρκετό».
#
# Προηγουμένως, ο διευθύνων σύμβουλος της Ring, Τζέημι Σίμινοφ, υπενθύμισε ότι η εταιρεία ξεκίνησε τη μέρα που δεν μπόρεσε να ακούσει το κουδούνι της πόρτας από το εργαστήριο στο γκαράζ του.
#
# Οι παραλίες της Βόρειας Ακτής (στο διαμέρισμα του Νορθ Χάρμπορ) βρέχονται από τον Ειρηνικό ωκεανό και εκτείνονται από το Λονγκ Μπέι στον Βορρά έως το Ντέβονπορτ στον Νότο.
#
# Ένα από τα δρώμενα που πραγματοποιούνται στην περιοχή και παρουσιάζουν μεγάλο ενδιαφέρον για τα παιδιά είναι η παράσταση ήχου και φωτός της πυραμίδας.
#
# Λίγο πριν το 2018, ο Σίμινοφ πήγε στον σταθμό τηλεμάρκετινγκ QVC.
#
# Βλέπετε τις πυραμίδες τη νύχτα με ησυχία προτού αρχίσει το σόου.
#
# Ενδέχεται να είναι πιο πολλές θάλασσες στην κοντινή μεριά, διότι ο φλοιός είναι αραιότερος. Η λάβα θα μπορούσε καλύτερα να πάει έτσι στην επιφάνεια.
#
# Η γη της Χαναάν δεν διέθετε μεγάλες δασικές εκτάσεις, επομένως το ξύλο ήταν πολύ ακριβό.
#
# Παρόλο που κάθε χώρα ήταν «σκανδιναβική», οι άνθρωποι, οι βασιλιάδες, τα έθιμα και η ιστορία της Δανίας, της Σουηδίας, της Νορβηγίας και της Ισλανδίας διέφεραν πολύ.
#
# Στην οπίσθια όψη της Διακήρυξης της Ανεξαρτησίας ήταν γραμμένο το εξής «Πρωτότυπη Διακήρυξη της Ανεξαρτησίας εκδοθείσα την 4η Ιουλίου 1776». Αυτό αναγράφεται κάτωθεν, αντίστροφα.
#
# Η ταινία, στην οποία συμμετέχουν ο Ράιαν Γκόσλινγκ και η Έμα Στόουν, έλαβε υποψηφιότητες σε όλες τις κύριες κατηγορίες.
#
# Υπολογίζοντας όλα τα στοιχεία, δεν μας εκπλήσσει ότι οι προγόνοι μας αντιμετώπισαν το «ζήτημα της πρωτεΐνης» όπως το κάνουν οι χιμπατζήδες στη σαβάνα αυτή τη στιγμή.
#
# Ο αναπληρωτής γενικός επιθεωρητής Ντ. Κ. Άρια δήλωσε: «Έχουμε συλλάβει πέντε άτομα που βίασαν την Ελβετή και έχουμε ανακτήσει το κινητό και το λάπτοπ της.
#
# Ο εκπρόσωπος των Γιατρών Χωρίς Σύνορα, Richard Veerman, δήλωσε πως «η Ανγκόλα οδεύει προς τη χειρότερη επιδημία όλων των εποχών και η κατάσταση παραμένει πολύ άσχημη στην Ανγκόλα».
#
# Ο πρόεδρος των Ηνωμένων πολιτειών Donald Trump σε δήλωση που διατυπώθηκε από την εκπρόσωπο Τύπου αργά την Κυριακή, ανακοίνωσε ότι τα στρατεύματα των ΗΠΑ θα αποχωρήσουν από τη Συρία.
#
# Ο θιβετιανός βουδισμός έχει ως βάση τις διδαχές του Βούδα, αλλά επεκτάθηκε από το μονοπάτι της αγάπης του μαχαγιάννα και από πολλές τεχνικές της ινδικής γιόγκα.
#
# Η εξήγηση που δίνει ο Άνχελ (2006) για την προσέγγιση της συνεχούς μάθησης την περιγράφει ως μια μέθοδο που χρησιμοποιείται για να βοηθήσει τους οργανισμούς να αφξίσουν το επίπεδο της απόδοσής τους.
#
# Όποιος πρόκειται να κινηθεί οδικά σε υψηλό υψόμετρο ή μέσα από ορεινά περάσματα, θα πρέπει να εξετάσει την πιθανότητα χιονιού, πάγου και πολύ χαμηλής θερμοκρασίας.
#
# Η ορατότητα επίσης μπορεί να περιοριστεί κατά τη χιονόπτωση, την υγρασία ή τον πάγο στα παράθυρα του οχήματος.
#
# Οι ταχύτητες των 802,11 n είναι ουσιωδώς μεγαλύτερες από ό,τι των προκατόχων τους με ανώτατη θεωρητική απόδοση 600 Mbit/δευτερόλεπτο.
#
# Στα τέλη του 2015, ο ΤόγκιΝετ ίδρυσε τον ΆστροΝετ Ρέιντιο ως θυγατρικό σταθμό.
#
# Η Σμύρνη είναι η τρίτη πιο μεγάλη πόλη της Τουρκίας με σχεδόν 3.7 εκατομμύρια κατοίκους, ο δεύτερος πιο μεγάλος λιμένας μετά την Κωνσταντινούπολη και ένα καθοριστικό σημείο συνάντησεις για μεταφορές..
#
# Ο Χου ενθάρρυνε τις αναπυσσόμενες χώρες «να αποφύγουν την παλιά μέθοδο του να ρυπαίνουν πρώτα και να καθαρίζουν αργότερα.»
#
# Η Νότια Αφρική έχει νικήσει την All Blacks (Νέα Ζηλανδία) σε έναν αγώνα του Πρωταθλήματος Ράγκμπι Γιούνιον Νότιου Ημισφαιρίου στο Στάδιο Ρόγιαλ Μπάφοκενγκ του Ρούστενμπουργκ στη Νότια Αφρική.
#
# Το υπουργείο αποκρίθηκε αποκαλώντας «πραγματικά λυπηρή» την αναβολή της αναφοράς της Apple.
#
# Το λεωφορείο Scotturb 403 εκτελεί συχνά δρομολόγια προς τη Sintra και σταματά στο Cabo da Roca.
#
# Ο σεισμός είχε το επίκεντρό του περίπου 20 χιλιόμετρα (15 μίλια) βόρεια-βορειοανατολικά του Ντίλον και περίπου 65 χιλιόμετρα (40 μίλια) νότια του Μπουτ.
#
# Υπήρξε αντιπαράθεση στον διάλογο όσον αφορά τις δαπάνες για την αρωγή και την ανοικοδόμηση στον απόηχο του τυφώνα Κατρίνα, τις οποίες κάποιοι υποστηρικτές του δημοσιονομικού συντηρητισμού χιουμοριστικά περιέγραψαν ως «Συμφωνία της Νέας Ορλεάνης του Μπους».
#
# Ο Τσέιμπερς υπέβαλε μήνυση κατά του Θεού για «τους εκτεταμένους θανάτους, τις καταστροφές και την τρομοκρατία που βιώνουν εκατομμύρια κάτοικοι του πλανήτη».
#
# Καταρτίστηκε και έγινε γυναικολόγος, ξεκίνησε να δουλεύει το 1959 στην κρατική κλινική θηλέων, Auckland.
#
# Η ιστορία που παρουσιάζεται στη γαλλική όπερα του Καμίγ Σεν-Σανς αφορά τη ζωή ενός καλλιτέχνη «η ζωή του οποίου άγεται και φέρεται από την αγάπη για τα ναρκωτικά και την Ιαπωνία».
#
# Το μέρος περικλείεται βόρεια από το Sahel, ενώ ο Ατλαντικός την περιφράζει στη νότια και δυτική πλευρά του τόπου.
#
# Οι κάτοικοι του Παρισιού φημίζονται για τον εγωκεντρισμό, την αγένεια και την αλαζονεία τους.
#
# Ο Ρόμπιν Ουτάπα κατέκτησε το υψηλότερο σκορ περιόδων, πραγματοποιώντας 70 τρεξίματα σε μόλις 41 μπαλιές χτυπώντας 11 τεσσάρια και 2 εξάρια.
#
# Η υπηρεσιακή πρωθυπουργός Τζούλια Γκίλαρντ υποστήριξε κατά τη διάρκεια της εκστρατείας των ομοσπονδιακών εκλογών του 2010 ότι πίστευε πως η Αυστραλία θα έπρεπε να γίνει αβασίλευτη δημοκρατία όταν τελειώσει η βασιλεία της βασίλισσας Ελισάβετ Β΄.
#
# Στα μέρη της ενδοχώρας της βόρειας Ινδίας και του Πακιστάν βάζουν στα κάρυ κυρίως γιαούρτι. Στη νότια και άλλα παραθαλάσσια μέρη της Ινδίας βάζουν κυρίως τον χυμό της καρύδας.
#
# Τίποτα δεν είναι ορατό πέρα από τον καθαρό, όμορφο ουρανό και τα πολλά τριγύρω βουνά. Πολύ λίγα πράγματα αυτού του κόσμου είναι ορατά ή μπορούν να ακουστούν από το εσωτερικό της σπηλιάς.
#
# Η δέσμευση της Βόρειας Κορέας χαρακτηρίστηκε από τον εκπρόσωπο του Μπους Γκόρντον Τζοντρόι ως «ένα μεγάλο βήμα προς την επίτευξη του στόχου της επαληθεύσιμης αποπυρηνικοποίησης της χερσονήσου της Κορέας».
#
# Το 1990 πραγματοποιήθηκε η προσθήκη του στον κατάλογο των μνημείων παγκόσμιας κληρονομιάς που βρίσκονται σε κίνδυνο, επειδή απειλείται από την άμμο της ερήμου.
#
# Τα αθλήματα κατάβασης στο χιόνι, τα οποία περιλαμβάνουν το σκι και το σνόουμπορντ, είναι δημοφιλή αθλήματα που περιλαμβάνουν την ολίσθηση σε κατηφορικό έδαφος που είναι καλυμμένο από χιόνι με σκι ή με σνόουμπορντ τοποθετημένα στα πόδια σας.
#
# Οι φόβοι για την έλλειψη μέσων μεταφοράς εγείρουν την πιθανότητα ο αγώνας να διεξαχθεί αναγκαστικά κεκλεισμένων των θυρών, χωρίς τους οπαδούς της ομάδας.
#
# Το σκι αποτελεί μια σημαντική ταξιδιωτική δραστηριότητα με πολλούς λάτρεις, που συχνά αποκαλούνται ski bums, να σχεδιάζουν ολόκληρες διακοπές για σκι σε μια συγκεκριμένη τοποθεσία.
#
# Αποτελεί ένα από τα πιο αξιοσημείωτα αξιοθέατα της Νοτίου Αφρικής και αναφέρεται ως το έμβλημα των Εθνικών Πάρκων της Νοτίου Αφρικής (SANParks).
#
# Η ιταλική προφορά διαθέτει μια σχετική ευκολία, καθώς η πλειονότητα των λέξεων προφέρονται όπως ακριβώς γράφονται.
#
# Το οροπέδιο της Γκίζας, ή «Νεκρόπολη της Γκίζας» που βρίσκεται στην Κοιλάδα των Νεκρών της Αιγύπτου, έχει διάφορες πυραμίδες (μεγαλύτερη των οποίων είναι η πυραμίδα του Χέοπα), μερικούς μικρούς τάφους, αρκετούς ναούς και τη σπουδαία Σφίγγα.
#
# Παρόλο που έφυγε από την εκπομπή το 1993, κράτηση την διάκριση του διοικητικού στελέχους και εξακολουθούσε να παίρνει για κάθε κύκλο πολλά εκατομμύρια για τα δικαιώματα.
#
# Μπορεί να γίνει πολύ λεπτό και να κολλήσει σε άλλα μέταλλα. Μπορεί να γίνει τόσο λεπτό που κάποιες φορές χρησιμοποιούταν ως διακόσμηση στις χειροποίητες εικόνες βιβλίων που ονομάζονται «εικονογραφημένα χειρόγραφα».
#
# Ο υψηλός Μεσαίωνας ακολούθησε τον πρώιμο Μεσαίωνα και προηγήθηκε του ύστερου Μεσαίωνα, ο οποίος βάσει συνθηκών τελειώνει περίπου το 1500.
#
# Σήμερα, η επιστήμη δείχνει ότι αυτή η τεράστια οικονομία του άνθρακα έχει βγάλει τη βιόσφαιρα από μία σταθερή κατάστασή της που έχει υποστηρίξει την εξέλιξη του ανθρώπινου είδους κατά τα τελευταία δύο εκατομμύρια χρόνια.
#
# Σε μια συνέντευξη που είχε δώσει είχε πει ότι η καινούργια μετάλλαξη «προκαλούσε μεγάλη ανησυχία λόγω του υψηλού ποσοστού θνησιμότητας».
#
# Διάσημοι τραγουδιστές από όλη τη χώρα παρουσίασαν μπατζάνς, ή αλλιώς λατρευτικά τραγούδια, στα πόδια του Σρι Σίαμ.
#
# Τα θηλυκά έχουν συνήθως μια στενή σύνδεση μεταξύ τους, καθώς αποτελούν μια μεγάλη οικογένεια από αδερφές και κόρες.
#
# Το χειριστήριο, καθώς μοιάζει με τηλεχειριστήριο τηλεόρασης, χρησιμοποιεί δύο αισθητήρες οι οποίοι τοποθετούνται κοντά στην τηλεόραση του χρήστη για τον τριγωνισμό της θέσης του σε τρισδιάστατο χώρο.
#
# Η Αργεντινή φημίζεται για το γεγονός ότι διαθέτει μια από τις καλύτερες ομάδες πόλο και παίκτες παγκοσμίως.
#
# Το κυριότερο τουρνουά ετησίως λαμβάνει χώρα τον τελευταίο μήνα του έτους στις πισίνες υδατοσφαίρισης του Λας Κανίτας.
#
# Ένα μάθημα, κανονικά, θα καλύψει όλα τα θέματα που συζητώνται εδώ με πολύ περισσότερη λεπτομέρεια, συνήθως λόγω της πρακτικής εξάσκησης.
#
# Αν επισκεφτείτε την Αρκτική ή την Ανταρκτική τον χειμώνα θα αποκομίσετε την εμπειρία της πολικής νύχτας, όταν ο ήλιος δεν ανατέλλει πάνω από τον ορίζοντα.
#
# Οι υπάλληλοι πρέπει συχνά να έχουν έγκριση των προϊσταμένων τους για κάθε απόφαση, και πρέπει να υπακούουν στις οδηγίες των ανωτέρων τους χωρίς αντιρρήσεις.
#
# Ενώ η κατασκευή πυραμίδων από πέτρα συνεχίστηκε μέχρι το τέλος του Παλαιού Βασιλείου, καμία δεν ξεπέρασε τις πυραμίδες της Γκίζας σε μέγεθος και τεχνική αρτιότητα στην κατασκευή.
#
# Εντούτοις, δεν θεωρείται ότι έχουν προκαλέσει ζημιά στο λεωφορείο.
#
# Αυτό το νέο περιβάλλον διαθέτει νέες πηγές και διαφορετικούς ανταγωνιστές, άρα ο νέος πληθυσμός θα χρειαστεί διαφορετικά χαρακτηριστικά ή προσαρμογές ώστε να είναι ισχυρός ανταγωνιστής συγκριτικά με αυτό που απαιτούνταν στο παρελθόν.
#
# «Έχασα την αδερφή μου και τη φίλη της, ενώ καθοδόν προς τα εκεί είδα δύο άτομα με ειδικές ανάγκες σε αναπηρικά καροτσάκια και άλλα άτομα να πηδούν από πάνω τους και να τους σπρώχνουν», δήλωσε o Αρμάντ Βερσάτσε.
#
# Από Αναφορές γίνεται φανερό ότι περίπου 9400 οικίες στο συγκεκριμένο μέρος βρίσκονται χωρίς παροχή νερού και σχεδόν 100 χωρίς πρόσβαση σε ηλεκτρικό ρεύμα.

# %%
output = open('devtest/deu_Latn.devtest.equivalents', 'w')

with open('devtest/deu_Latn.devtest', 'r') as f:
    f = f.readlines()
    for a in z:
        output.write(f[a])
        print(f[a])
output.close()
# Out:
# Apia ist die auf der Insel Upolu liegende Hauptstadt von Samoa und weist eine Einwohnerzahl von knapp unter 40.000 auf.
#
# Man erwartet vielleicht nicht, dass auch zurückkehrenden Reisenden gegenüber Geduld und Verständnis erforderlich sind.
#
# Wie einige andere Experten zeigte er sich skeptisch, ob es möglich sei, Diabetes zu heilen, und wies darauf hin, dass die Befunde für Menschen, die bereits unter Typ-1-Diabetes litten, keine Bedeutung hätten.
#
# Gerichte des alten Roms konnten keine Nahrungsmittel enthalten, die in späteren Jahrhunderten aus Amerika oder Asien nach Europa kamen.
#
# Danius sagte: „Im Moment unternehmen wir nichts. Ich habe seinen engsten Mitarbeiter angerufen und ihm E-Mails geschickt und sehr freundliche Antworten erhalten. Das ist vorläufig genug.“
#
# Rings CEO Jamie Siminoff sagte einmal, dass er das Unternehmen gegründet habe, nachdem er von seiner Garagenwerkstatt aus seine Türklingel nicht hören konnte.
#
# Die Strände von North Shore (im Bezirk North Harbour) liegen am Pazifischen Ozean und erstrecken sich von Long Bay im Norden bis Devonport im Süden.
#
# Die Klang- und Lichtshow bei den Pyramiden ist eine der interessantesten Attraktionen für Kinder in der Gegend.
#
# Ende 2017 trat Siminoff im Teleshopping-Sender QVC auf.
#
# Sie können die Pyramiden in der Dunkelheit sehen und während es still ist, ehe die Show beginnt.
#
# Auf der Nahseite könnte es mehr Maria geben, da die Kruste dünner ist. Es war einfacher für die Lava, an die Oberfläche aufzusteigen.
#
# Im Land Kanaan gab es keine großen Wälder, so dass Holz extrem teuer war.
#
# Obwohl alle Länder „skandinavisch“ waren, gab es viele Unterschiede zwischen den Menschen, den Königen, den Bräuchen und der Geschichte von Dänemark, Schweden, Norwegen und Island.
#
# Auf die Rückseite der Unabhängigkeitserklärung waren die Worte „ursprüngliche Unabhängigkeitserklärung, datiert auf den 4. Juli 1776“ geschrieben. Der Text befindet sich kopfüber an der Unterseite des Dokuments.
#
# Der Film mit Ryan Gosling und Emma Stone hat Nominierungen in allen Hauptkategorien erhalten.
#
# Insgesamt sollte es uns nicht überraschen, wenn unsere eigenen Vorfahren ihr „Proteinproblem“ auf ähnliche Weise gelöst haben, wie es die Schimpansen in der Savanne heute tun.
#
# Der stellvertretende Generalinspekteur D. K. Arya sagte: „Wir haben fünf Personen festgenommen, die die Schweizerin vergewaltigt haben, und ihr Handy und Laptop sichergestellt.“
#
# "Richard Veerman, Sprecher von Ärzte ohne Grenzen, sagte: „Angola steuert auf den schlimmsten Ausbruch aller Zeiten zu, und die Lage in Angola ist nach wie vor sehr schlecht."""
#
# Am späten Sonntag kündigte der Präsident der Vereinigten Staaten, Donald Trump, in einer durch den Pressesekretär verlesenen Erklärung an, dass die US-Truppen Syrien verlassen würden.
#
# Der tibetanische Buddhismus basiert auf den Lehren Buddhas, wurde aber um den Pfad der Liebe des Mahayana und zahlreiche Techniken des indischen Yoga erweitert.
#
# Angel (2006) erläutert das Kontinuum-Konzept als eine Methode, um Organisationen zu helfen, leistungsfähiger zu werden.
#
# Wer in hohen Breiten oder über Gebirgspässe fahren will, sollte mit Schnee, Eis und Temperaturen unter dem Gefrierpunkt rechnen.
#
# Die Sichtweite kann auch durch fallenden oder umherwehenden Schnee oder durch Kondensation oder Eis auf den Fahrzeugfenstern beeinträchtigt werden.x
#
# Die Geschwindigkeit von 802,11 n ist wesentlich schneller als die der Vorgänger, die einen maximalen theoretischen Durchsatz von 600 Mbit/s hatten.
#
# Ende 2015 gründete TogiNet die Nebenstation AstroNet Radio.
#
# Izmir ist die drittgrößte Stadt der Türkei mit einer Bevölkerung von etwa 3,7 Millionen, dem zweitgrößten Hafen nach Istanbul und einem sehr guten Verkehrsdrehkreuz.
#
# Hu ermutigte Entwicklungsländer „den alten Weg von erst verschmutzen und hinterher aufzuräumen, zu vermeiden“.
#
# Südafrika hat die All Blacks (Neuseeland) in einem Rugby-Union-Match im Drei-Nationen-Turnier im Royal-Bafokeng-Stadion im südafrikanischen Rustenburg besiegt.
#
# Das Ministerium reagierte, indem es die Verschiebung des Berichts durch Apple als „wirklich bedauerlich“ bezeichnete.
#
# Der Scotturb-Bus 403 fährt regelmäßig über Cabo da Roca nach Sintra.
#
# Das Zentrum des Erdbebens befand sich etwa 20 km (15 Meilen) nordnordöstlich von Dillon und etwa 65 km (40 Meilen) südlich von Butte.
#
# "Auslöser der Debatte war eine Kontroverse über die Ausgaben für die Nothilfe und den Wiederaufbau nach dem Hurrikan Katrina, die einige fiskalisch Konservative humorvoll als ""Bushs New Orleans-Deal"" bezeichnet haben. "
#
# Chambers verklagte Gott wegen „weitverbreitetem Tod, Zerstörung und Terrorisierung von vielen Millionen Erdbewohnern“.
#
# Er machte eine Ausbildung als Entbindungsarzt und nahm 1959 seine Arbeit im National Women's Hospital in Auckland auf.
#
# Die Geschichte, die in der französischen Oper von Camille Saint-Saens vorgestellte wurde, handelt von einem Künstler, „dessen Leben von der Liebe zu Drogen und Japan bestimmt ist“.
#
# Im Norden ist die Region von der Sahelzone begrenzt und im Süden und Westen vom Atlantischen Ozean.
#
# Parisern sagt man nach, egozentrisch, unhöflich und arrogant zu sein.
#
# Robin Uthappa erreichte die höchste Punktzahl der Innings, 70 Punkte bei nur 41 Bällen, indem er 11 Vierer und 2 Sechser schlug.
#
# Die vorübergehend amtierende Premierministerin Julia Gillard erklärte während des Wahlkampfes für die Bundeswahl 2010, dass ihrer Meinung nach Australien am Ende der Herrschaft von Königin Elizabeth II eine Republik werden sollte.
#
# Im Landesinneren Nordindiens und Pakistans wird Joghurt üblicherweise in Currys verwendet; in Südindien und einigen anderen Küstenregionen des Subkontinents wird üblicherweise Kokosmilch verwendet.
#
# Man sieht nichts außer dem darüber liegenden, klaren, wunderschönen Himmel und den zahlreichen umliegenden Bergen. Vom Innern der Höhle aus ist sehr wenig von dieser Welt zu sehen oder zu hören.
#
# "Bush-Sprecher Gordon Johndroe nannte das Versprechen Nordkoreas „einen wichtigen Schritt in Richtung des Ziels, die verifizierbare Entnuklearisierung der koreanischen Halbinsel zu erreichen."""
#
# Im Jahr 1990 wurde es aufgrund der Bedrohung durch Wüstensand zur Liste der gefährdeten Weltkulturerbegebiete hinzugefügt.
#
# Abfahrtssport wie Ski- und Snowboardfahren sind beliebte Sportarten, bei denen man Skier oder ein Snowboard an seinen Füßen befestigt und über einen schneebedeckten Untergrund einen Abhang hinabfährt.
#
# Mit der Sorge um mangelnde Transportmöglichkeiten wuchs die Wahrscheinlichkeit, dass das Spiel ohne die Fans der Mannschaft hinter verschlossenen Türen ausgetragen werden müsse.
#
# Skifahren ist eine beliebte Reisetätigkeit mit vielen Enthusiasten, gelegentlich auch als „Skipenner“ bekannt, die ihren gesamten Urlaub rund um das Skifahren an einem bestimmten Ort planen.
#
# Er ist einer der Hauptanziehungspunkte Südafrikas und gilt als das Aushängeschild der Südafrikanischen Nationalparks (SANParks).
#
# Die italienische Aussprache ist relativ einfach, da die meisten Wörter genau so ausgesprochen werden, wie sie geschrieben sind.
#
# Das Gizeh-Plateau beziehungsweise die „Gizeh-Nekropole“ im ägyptischen Tal der Toten umfasst mehrere Pyramiden (von denen die Große Pyramide die größte ist), mehrere kleine Gräber, mehrere Tempel sowie die große Sphinx.
#
# Obwohl er die Show 1993 verließ, behielt er den Titel des Chefproduzenten und erhielt weiterhin in jeder Saison Lizenzgebühren in zweistelliger Millionenhöhe.
#
# Es kann sehr dünn gefertigt und auf anderes Metall geklebt werden. Es kann derart dünn gemacht werden, dass es manchmal dazu verwenwurde, um handgemalte Bilder, genannt Bilderhandschriften, in Büchern zu dekorieren, die Bilderhandschriften genannt werden.
#
# Dem Hochmittelalter ging das Frühmittelalter voraus, gefolgt vom Spätmittelalter, das übereinstimmend um 1500 endet.
#
# Die Wissenschaft weist nun darauf hin, dass diese massive Kohlenstoffwirtschaft die Biosphäre aus einem ihrer stabilen Zustände, der die menschliche Evolution in den letzten zwei Millionen Jahren getragen hat, herausgebracht hat.
#
# "In einem Interview sagte er, die neue Variante sei „äußerst beunruhigend und alarmierend aufgrund der sehr hohen Sterblichkeitsrate."""
#
# Berühmte Sänger im ganzen Land präsentierten Bhajans, Andachtslieder, zu Shri Shyams Füßen.
#
# Frauen haben normalerweise eine enge Beziehung zueinander, wenn sie in einer großen Familie mit Schwestern und Töchtern leben.
#
# Ähnlich einer TV-Fernbedienung verwendet der Controller zwei Sensoren, die in der Nähe des Fernsehers des Benutzers platziert werden, um dessen Position im dreidimensionalen Raum zu triangulieren.
#
# Argentinien ist bekannt dafür, dass sein Polo-Team und die Spieler zu den besten der Welt gehören.
#
# Das größte Turnier des Jahres findet im Dezember auf Las Cañitas Polofeldern statt.
#
# Ein Kurs deckt alle hier diskutierten Probleme in der Regel viel detaillierter ab, normalerweise in Kombination mit praktischer Erfahrung.
#
# Wenn Sie die Arktik- oder Antarktik-Gegenden im Winter besuchen, werden Sie die Polarnacht erleben, was bedeutet, dass die Sonne nicht über den Horizont steigt.
#
# Oftmals müssen Arbeitnehmer für alle Entscheidungen, die sie treffen, die Zustimmung ihrer Vorgesetzten einholen und es wird von ihnen erwartet, dass sie den Anweisungen ihrer Chefs bedingungslos Folge leisten.
#
# Obwohl der Bau von Pyramiden aus Stein bis zum Ende des Alten Reiches fortgesetzt wurde, wurden die Pyramiden von Gizeh in ihrer Größe und der technischen Perfektion ihrer Konstruktion nie übertroffen.
#
# Man geht allerdings nicht davon aus, dass sie das Shuttle in irgendeiner Weise beschädigt haben.
#
# Dieses neue Umfeld hat andere Ressourcen und andere Konkurrenten, so dass die neue Bevölkerung andere Merkmale oder Anpassungen benötigt, um ein starker Konkurrent zu sein, als das, was sie vorher gebraucht hat.
#
# "„Ich habe meine Schwester und ihre Freundin verloren, und auf meinem Weg waren zwei Behinderte im Rollstuhl, über die Leute einfach drübergesprungen sind und sie geschubst haben"", sagte Armand Versace."
#
# Es wird berichtet, dass etwa 9.400 Häuser in der Region kein Wasser und ungefähr 100 keinen Strom haben.
